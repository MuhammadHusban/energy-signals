# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from keras.utils import to_categorical
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv("/content/dataM.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Total floor area (m²)  \
# 0           0                   45.0
# 1           1                  143.0
# 2           2                   65.0
# 3           3                   49.0
# 4           4                  212.0
#
#    Total current energy costs over 3 years (£)  \
# 0                                       3771.0
# 1                                       2793.0
# 2                                       1947.0
# 3                                       1158.0
# 4                                       6477.0
#
#    Current hot water costs over 3 years (£) Part 1 Construction Age Band  \
# 0                                    1176.0                  before 1919
# 1                                     375.0                    2003-2007
# 2                                     441.0                  before 1919
# 3                                     195.0                    1999-2002
# 4                                     819.0                  before 1919
#
#    Part 1 Floor 0 Room Height  Low Energy Lighting % Mechanical Ventilation  \
# 0                        3.10                    100                natural
# 1                        2.40                    100                natural
# 2                        2.45                    100                natural
# 3                        2.40                    100                natural
# 4                        2.80                     64                natural
#
#              Tenure   Transaction Type  ... insulated_wall  \
# 0    owner-occupied  none of the above  ...              0
# 1    owner-occupied      marketed sale  ...              1
# 2    owner-occupied      marketed sale  ...              0
# 3  rented (private)  none of the above  ...              1
# 4    owner-occupied      marketed sale  ...              1
#
#                 wall_type  roof_type floor_type windows_glazing MMH_mains gas  \
# 0  sandstone or limestone    Pitched    Unknown   double glazed         False
# 1             cavity wall    Pitched  Suspended   double glazed          True
# 2  sandstone or limestone    Unknown      Solid   single glazed          True
# 3             cavity wall    Unknown  Suspended   double glazed          True
# 4    granite or whinstone    Pitched      Solid   double glazed         False
#
#   MHCS_programmer                               low_lighting  SH_room heaters  \
# 0            True  low energy lighting 100% of fixed outlets            False
# 1            True  low energy lighting 100% of fixed outlets            False
# 2            True  low energy lighting 100% of fixed outlets            False
# 3            True  low energy lighting 100% of fixed outlets            False
# 4            True   low energy lighting 60% of fixed outlets             True
#
#   Current energy efficiency rating band
# 0                                     E
# 1                                     C
# 2                                     C
# 3                                     C
# 4                                     E
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#        Unnamed: 0  Total floor area (m²)  \
# 54490       54490                   74.0
# 54491       54491                  228.0
# 54492       54492                  123.0
# 54493       54493                   59.0
# 54494       54494                   77.0
#
#        Total current energy costs over 3 years (£)  \
# 54490                                        996.0
# 54491                                       4674.0
# 54492                                       2292.0
# 54493                                        972.0
# 54494                                        978.0
#
#        Current hot water costs over 3 years (£) Part 1 Construction Age Band  \
# 54490                                     210.0                  before 1919
# 54491                                    1491.0                 2008 onwards
# 54492                                     753.0                  before 1919
# 54493                                     276.0                  before 1919
# 54494                                     303.0                  before 1919
#
#        Part 1 Floor 0 Room Height  Low Energy Lighting %  \
# 54490                        2.40                    100
# 54491                        2.40                    100
# 54492                        2.43                    100
# 54493                        2.41                    100
# 54494                        2.40                    100
#
#                Mechanical Ventilation           Tenure   Transaction Type  \
# 54490                         natural   owner-occupied       new dwelling
# 54491                         natural   owner-occupied  none of the above
# 54492  mechanical, supply and extract          unknown       new dwelling
# 54493                         natural  rented (social)       new dwelling
# 54494                         natural  rented (social)       new dwelling
#
#        ... insulated_wall     wall_type  roof_type floor_type  \
# 54490  ...              0       Unknown    Unknown    Unknown
# 54491  ...              1  timber frame    Pitched      Solid
# 54492  ...              0       Unknown    Unknown    Unknown
# 54493  ...              0       Unknown    Unknown    Unknown
# 54494  ...              0       Unknown    Unknown    Unknown
#
#                 windows_glazing MMH_mains gas MHCS_programmer  \
# 54490  high performance glazing          True            True
# 54491             double glazed         False           False
# 54492  high performance glazing         False           False
# 54493  high performance glazing          True           False
# 54494  high performance glazing          True           False
#
#                                     low_lighting  SH_room heaters  \
# 54490  low energy lighting 100% of fixed outlets            False
# 54491  low energy lighting 100% of fixed outlets            False
# 54492  low energy lighting 100% of fixed outlets            False
# 54493  low energy lighting 100% of fixed outlets            False
# 54494  low energy lighting 100% of fixed outlets            False
#
#       Current energy efficiency rating band
# 54490                                     B
# 54491                                     C
# 54492                                     B
# 54493                                     B
# 54494                                     B
#
# [5 rows x 22 columns]

# %%
df.describe()
# Out:
#          Unnamed: 0  Total floor area (m²)  \
# count  54495.000000           54495.000000
# mean   27247.000000              88.604865
# std    15731.495797              50.635685
# min        0.000000              15.000000
# 25%    13623.500000              62.000000
# 50%    27247.000000              77.000000
# 75%    40870.500000              98.000000
# max    54494.000000             983.024000
#
#        Total current energy costs over 3 years (£)  \
# count                                 54495.000000
# mean                                   2682.322298
# std                                    2045.518883
# min                                     552.000000
# 25%                                    1527.000000
# 50%                                    2115.000000
# 75%                                    3114.000000
# max                                   46076.267400
#
#        Current hot water costs over 3 years (£)  Part 1 Floor 0 Room Height  \
# count                              54495.000000                54495.000000
# mean                                 407.240972                    2.501650
# std                                  311.853653                    0.258544
# min                                   57.000000                    1.000000
# 25%                                  234.000000                    2.360000
# 50%                                  279.000000                    2.400000
# 75%                                  450.000000                    2.570000
# max                                 3370.127700                    5.657008
#
#        Low Energy Lighting %  insulated_wall
# count           54495.000000    54495.000000
# mean               85.418112        0.576255
# std                22.454020        0.494156
# min                 1.000000        0.000000
# 25%                75.000000        0.000000
# 50%               100.000000        1.000000
# 75%               100.000000        1.000000
# max               100.000000        1.000000

# %%
df.isnull()
# Out:
#        Unnamed: 0  Total floor area (m²)  \
# 0           False                  False
# 1           False                  False
# 2           False                  False
# 3           False                  False
# 4           False                  False
# ...           ...                    ...
# 54490       False                  False
# 54491       False                  False
# 54492       False                  False
# 54493       False                  False
# 54494       False                  False
#
#        Total current energy costs over 3 years (£)  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 54490                                        False
# 54491                                        False
# 54492                                        False
# 54493                                        False
# 54494                                        False
#
#        Current hot water costs over 3 years (£)  Part 1 Construction Age Band  \
# 0                                         False                         False
# 1                                         False                         False
# 2                                         False                         False
# 3                                         False                         False
# 4                                         False                         False
# ...                                         ...                           ...
# 54490                                     False                         False
# 54491                                     False                         False
# 54492                                     False                         False
# 54493                                     False                         False
# 54494                                     False                         False
#
#        Part 1 Floor 0 Room Height  Low Energy Lighting %  \
# 0                           False                  False
# 1                           False                  False
# 2                           False                  False
# 3                           False                  False
# 4                           False                  False
# ...                           ...                    ...
# 54490                       False                  False
# 54491                       False                  False
# 54492                       False                  False
# 54493                       False                  False
# 54494                       False                  False
#
#        Mechanical Ventilation  Tenure  Transaction Type  ...  insulated_wall  \
# 0                       False   False             False  ...           False
# 1                       False   False             False  ...           False
# 2                       False   False             False  ...           False
# 3                       False   False             False  ...           False
# 4                       False   False             False  ...           False
# ...                       ...     ...               ...  ...             ...
# 54490                   False   False             False  ...           False
# 54491                   False   False             False  ...           False
# 54492                   False   False             False  ...           False
# 54493                   False   False             False  ...           False
# 54494                   False   False             False  ...           False
#
#        wall_type  roof_type  floor_type  windows_glazing  MMH_mains gas  \
# 0          False      False       False            False          False
# 1          False      False       False            False          False
# 2          False      False       False            False          False
# 3          False      False       False            False          False
# 4          False      False       False            False          False
# ...          ...        ...         ...              ...            ...
# 54490      False      False       False            False          False
# 54491      False      False       False            False          False
# 54492      False      False       False            False          False
# 54493      False      False       False            False          False
# 54494      False      False       False            False          False
#
#        MHCS_programmer  low_lighting  SH_room heaters  \
# 0                False         False            False
# 1                False         False            False
# 2                False         False            False
# 3                False         False            False
# 4                False         False            False
# ...                ...           ...              ...
# 54490            False         False            False
# 54491            False         False            False
# 54492            False         False            False
# 54493            False         False            False
# 54494            False         False            False
#
#        Current energy efficiency rating band
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ...                                      ...
# 54490                                  False
# 54491                                  False
# 54492                                  False
# 54493                                  False
# 54494                                  False
#
# [54495 rows x 22 columns]

# %%
df.value_counts()
# Out:
# Unnamed: 0  Total floor area (m²)  Total current energy costs over 3 years (£)  Current hot water costs over 3 years (£)  Part 1 Construction Age Band  Part 1 Floor 0 Room Height  Low Energy Lighting %  Mechanical Ventilation  Tenure            Transaction Type   wall_insulation           roof_insulation         insulated_wall  wall_type               roof_type  floor_type         windows_glazing           MMH_mains gas  MHCS_programmer  low_lighting                               SH_room heaters  Current energy efficiency rating band
# 0           45.0                   3771.0                                       1176.0                                    before 1919                   3.100                       100                    natural                 owner-occupied    none of the above  no insulation             150 mm loft insulation  0               sandstone or limestone  Pitched    Unknown            double glazed             False          True             low energy lighting 100% of fixed outlets  False            E                                        1
# 36322       91.0                   2484.0                                       279.0                                     1930-1949                     2.400                       100                    natural                 rented (social)   marketed sale      with external insulation  300 mm loft insulation  1               system built            Pitched    Solid              double glazed             True           True             low energy lighting 100% of fixed outlets  True             C                                        1
# 36324       70.0                   1761.0                                       198.0                                     1950-1964                     2.400                       100                    natural                 owner-occupied    none of the above  filled cavity             200 mm loft insulation  1               cavity wall             Pitched    Suspended          double glazed             True           True             low energy lighting 100% of fixed outlets  False            C                                        1
# 36325       53.0                   1014.0                                       216.0                                     2008 onwards                  2.400                       100                    natural                 owner-occupied    marketed sale      insulated                 300 mm loft insulation  1               timber frame            Unknown    Solid              double glazed             True           True             low energy lighting 100% of fixed outlets  False            B                                        1
# 36326       85.0                   5610.0                                       501.0                                     before 1919                   2.800                       100                    natural                 rented (private)  rental             no insulation             150 mm loft insulation  0               granite or whinstone    Pitched    Solid              double glazed             False          True             low energy lighting 100% of fixed outlets  True             F                                        1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ..
# 18168       47.0                   2037.0                                       516.0                                     1984-1991                     2.360                       100                    natural                 rented (social)   rental             insulated                 250 mm loft insulation  1               cavity wall             Pitched    Unknown            double glazed             True           False            low energy lighting 100% of fixed outlets  True             C                                        1
# 18169       42.0                   1803.0                                       207.0                                     before 1919                   3.100                       100                    natural                 owner-occupied    none of the above  no insulation             no insulation           0               sandstone or limestone  Pitched    Unknown            double glazed             True           True             low energy lighting 100% of fixed outlets  False            D                                        1
# 18170       83.0                   2721.0                                       600.0                                     1950-1964                     2.440                       33                     natural                 owner-occupied    marketed sale      filled cavity             270 mm loft insulation  1               cavity wall             Pitched    Suspended          double glazed             True           True             low energy lighting 30% of fixed outlets   True             D                                        1
# 18171       45.0                   1707.0                                       549.0                                     1965-1975                     2.424                       100                    natural                 rented (social)   RHI application    no insulation             300 mm loft insulation  0               system built            Unknown    To unheated space  double glazed             False          True             low energy lighting 100% of fixed outlets  False            C                                        1
# 54494       77.0                   978.0                                        303.0                                     before 1919                   2.400                       100                    natural                 rented (social)   new dwelling       no insulation             300 mm loft insulation  0               Unknown                 Unknown    Unknown            high performance glazing  True           False            low energy lighting 100% of fixed outlets  False            B                                        1
# Length: 54495, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54495 entries, 0 to 54494
# Data columns (total 22 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unnamed: 0                                   54495 non-null  int64
#  1   Total floor area (m²)                        54495 non-null  float64
#  2   Total current energy costs over 3 years (£)  54495 non-null  float64
#  3   Current hot water costs over 3 years (£)     54495 non-null  float64
#  4   Part 1 Construction Age Band                 54495 non-null  object
#  5   Part 1 Floor 0 Room Height                   54495 non-null  float64
#  6   Low Energy Lighting %                        54495 non-null  int64
#  7   Mechanical Ventilation                       54495 non-null  object
#  8   Tenure                                       54495 non-null  object
#  9   Transaction Type                             54495 non-null  object
#  10  wall_insulation                              54495 non-null  object
#  11  roof_insulation                              54495 non-null  object
#  12  insulated_wall                               54495 non-null  int64
#  13  wall_type                                    54495 non-null  object
#  14  roof_type                                    54495 non-null  object
#  15  floor_type                                   54495 non-null  object
#  16  windows_glazing                              54495 non-null  object
#  17  MMH_mains gas                                54495 non-null  bool
#  18  MHCS_programmer                              54495 non-null  bool
#  19  low_lighting                                 54495 non-null  object
#  20  SH_room heaters                              54495 non-null  bool
#  21  Current energy efficiency rating band        54495 non-null  object
# dtypes: bool(3), float64(4), int64(3), object(12)
# memory usage: 8.1+ MB

# %%
# Split data into features and labels
X = df.drop("Current energy efficiency rating band", axis=1)
y = df["Current energy efficiency rating band"]
encoder = LabelEncoder()
y= encoder.fit_transform(y)

# One-hot encode labels
y = to_categorical(y, num_classes=7)

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Define which columns are categorical and which are numerical
categorical_cols = ["Part 1 Construction Age Band", "Mechanical Ventilation", "Tenure", "Transaction Type",
                   "wall_insulation", "roof_insulation", "wall_type", "roof_type", "floor_type",
                   "windows_glazing", "low_lighting"]
numerical_cols = ["Total floor area (m²)", "Total current energy costs over 3 years (£)",
                  "Current hot water costs over 3 years (£)", "Part 1 Floor 0 Room Height",
                  "Low Energy Lighting %", "insulated_wall", "MMH_mains gas", "MHCS_programmer",
                  "SH_room heaters"]

# %%
# Create ColumnTransformer to handle different data types
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_cols),
        ('cat', OneHotEncoder(), categorical_cols)])

# %%
# Fit and transform the data using the ColumnTransformer
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dropout(0.5))  # Adding dropout to prevent overfitting
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))  # Adding dropout to prevent overfitting
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))  # Adding dropout to prevent overfitting
model.add(Dense(7, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train,validation_data = (X_test,y_test), epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/sequential/dense/embedding_lookup_sparse/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/sequential/dense/embedding_lookup_sparse/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/sequential/dense/embedding_lookup_sparse/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# 1363/1363 [==============================] - 8s 5ms/step - loss: 0.9754 - accuracy: 0.6238 - val_loss: 0.5878 - val_accuracy: 0.7858
# Epoch 2/10
# 1363/1363 [==============================] - 10s 7ms/step - loss: 0.6891 - accuracy: 0.7334 - val_loss: 0.5064 - val_accuracy: 0.8095
# Epoch 3/10
# 1363/1363 [==============================] - 11s 8ms/step - loss: 0.6062 - accuracy: 0.7696 - val_loss: 0.4647 - val_accuracy: 0.8257
# Epoch 4/10
# 1363/1363 [==============================] - 5s 3ms/step - loss: 0.5672 - accuracy: 0.7869 - val_loss: 0.4356 - val_accuracy: 0.8358
# Epoch 5/10
# 1363/1363 [==============================] - 5s 3ms/step - loss: 0.5392 - accuracy: 0.7989 - val_loss: 0.4292 - val_accuracy: 0.8368
# Epoch 6/10
# 1363/1363 [==============================] - 5s 3ms/step - loss: 0.5232 - accuracy: 0.8042 - val_loss: 0.4168 - val_accuracy: 0.8416
# Epoch 7/10
# 1363/1363 [==============================] - 5s 3ms/step - loss: 0.5112 - accuracy: 0.8105 - val_loss: 0.4028 - val_accuracy: 0.8492
# Epoch 8/10
# 1363/1363 [==============================] - 5s 3ms/step - loss: 0.4999 - accuracy: 0.8151 - val_loss: 0.4220 - val_accuracy: 0.8363
# Epoch 9/10
# 1363/1363 [==============================] - 5s 3ms/step - loss: 0.4926 - accuracy: 0.8143 - val_loss: 0.4003 - val_accuracy: 0.8463
# Epoch 10/10
# 1363/1363 [==============================] - 5s 3ms/step - loss: 0.4937 - accuracy: 0.8184 - val_loss: 0.3940 - val_accuracy: 0.8456

# %%
# Evaluate model
score = model.evaluate(X_test, y_test)
print("Test loss: ", score[0])
print("Test accuracy: ", score[1])
# Out:
# 341/341 [==============================] - 1s 2ms/step - loss: 0.3940 - accuracy: 0.8456
# Test loss:  0.39401233196258545
# Test accuracy:  0.8455821871757507

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# Compute the predicted probabilities for each class
y_pred_proba = model.predict(X_test)

# Compute the average AUC score across all classes
auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')
print('Average AUC:', auc)

# Compute the FPR and TPR for each class
fpr = dict()
tpr = dict()
for i in range(7):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred_proba[:, i])

# Plot the ROC curve for each class
plt.figure()
for i in range(7):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {}'.format(i))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curves for multiclass output')
plt.legend(loc="lower right")
plt.show()
# Out:
# 341/341 [==============================] - 1s 1ms/step
# Average AUC: 0.9704730751527849
